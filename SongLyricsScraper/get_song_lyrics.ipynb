# %%
client_id = "JxFUHlJQmqzccAW5XmwkaeDuL3P1S3h5XNRJ4a2U4guuov04XdbI8k2FTF1mvQ4x"
client_secret = "D0OsAzJISwVnlIk-wE6DWgSvkPzqEyjdRJgiMRgxEjcc2r0di0_I9ALnZbNmwxhzkSZv8YoF4WwZztKNlJU1-Q"
client_access_token = "CNJOsm6ICvn4yaTomXohdsi0iJvEPoCnMnrVU5Y15-nbQ62lDvG2htyKu-GIv8Q_"

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /srv/conda/lib/python3.9/site-packages (2.31.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.9/site-packages (from requests) (2022.12.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.9/site-packages (from requests) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.9/site-packages (from requests) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /srv/conda/lib/python3.9/site-packages (from requests) (3.1.0)

# %%
import pandas as pd
import os.path
import csv
import time
import requests
from bs4 import BeautifulSoup
from IPython.display import clear_output, display, HTML, Javascript

# %%
base_url = "http://api.genius.com"
headers={'Authorization': 'Bearer CNJOsm6ICvn4yaTomXohdsi0iJvEPoCnMnrVU5Y15-nbQ62lDvG2htyKu-GIv8Q_'}

def song_info_from_song_id(song_id):
    page_url = "http://genius.com/songs/" + str(song_id)
    page = requests.get(page_url)
    html = BeautifulSoup(page.content, "html.parser")
    #remove script tags that they put in the middle of the lyrics
    [h.extract() for h in html('script')]
    #at least Genius is nice and has a tag called 'lyrics'!
    lyrics_list = html.find_all("div", class_="Lyrics__Container-sc-1ynbvzw-1")
    lyrics = " ".join([x.get_text("\n") for x in lyrics_list])
    description_list = html.find_all("div", class_="SongDescription__Container-sc-615rvk-0")
    description = " ".join([x.get_text() for x in description_list])
    with csv_writer_lock:
        # change this to whatever you want your final data file to be called
        with open("all_songs.csv", mode="a") as f1:
            review_writer = csv.writer(f1, delimiter=",")
            review_writer.writerow([song_id, lyrics, description])
    return lyrics, description

# %%
from concurrent.futures import ThreadPoolExecutor
import threading
csv_writer_lock = threading.Lock()

# %%
# setting up threads bc so slow
def set_up_threads(ids):
    with ThreadPoolExecutor(max_workers=7) as executor:
        return executor.map(song_info_from_song_id,
                            ids,
                            timeout = 60)

# %%
# change this to whatever your song csv is called (from getting song id notebook)
songs_df = pd.read_csv("top35189songs.csv")

# %%
# RUNNN (change all_songs.csv to name of your final csv file)
pd.DataFrame(columns=["id", "lyrics", "annotation"]).to_csv("all_songs.csv", index=False)
set_up_threads(list(songs_df["song_id"]))
# Out:
# <generator object Executor.map.<locals>.result_iterator at 0x7fde88b6a900>

# %%
pd.DataFrame(columns=["id", "lyrics", "annotation"]).to_csv("all_songs.csv", index=False)

# %%
df = pd.read_csv("all_songs.csv")
df
# Out:
#             id                                             lyrics  \
# 0      3834209  [Verse 1: Anne-Marie]\nI will always remember\...
# 1       572269  [Verse 1: Harry]\nI got a heart and I got a so...
# 2      3932728  [Verse 1: Saweetie]\nOoh, I think they like me...
# 3      6382271  [Intro]\nOh, oh\n[Verse 1: Ghetts]\nLet me get...
# 4      4575103  [Chorus: Ed Sheeran]\nOh, I been on for a thou...
# ...        ...                                                ...
# 35184  5644540                                                NaN
# 35185  5644661                                                NaN
# 35186   193461  [Verse 1]\nI, I was the game he would play\nHe...
# 35187   218073  [Intro]\nYou wanna?\nYou wanna?\n[Chorus]\nYou...
# 35188   459924  [Intro]\nCrazy\nOh, oh, oh oh\n[Verse 1]\nBaby...
#
#                                               annotation
# 0      Have the inside scoop on this song?Sign up and...
# 1      This song bio is unreviewedGenius Annotation1 ...
# 2      Have the inside scoop on this song?Sign up and...
# 3      Have the inside scoop on this song?Sign up and...
# 4      Genius Annotation2 contributors“1000 Nights” i...
# ...                                                  ...
# 35184  This song bio is unreviewedGenius Annotation1 ...
# 35185  This song bio is unreviewedGenius Annotation1 ...
# 35186  Genius Annotation2 contributors\n“You Got It A...
# 35187  Genius Annotation4 contributorsIn this hard-hi...
# 35188  Genius Annotation1 contributor“(You Drive Me) ...
#
# [35189 rows x 3 columns]

# %%
def clean_description(description):
    if "Expand +" in description and " contributors" in description:
        return description.split("Expand +")[0].split(" contributors")[1]
    elif "Expand +" in description and " contributor" in description:
        return description.split("Expand +")[0].split(" contributor")[1]
    elif "Expand +" in description:
        return description.split("Expand +")[0]
    elif " contributors" in description:
        return description.split(" contributors")[1]
    elif " contributor" in description:
        return description.split(" contributor")[1]
    return description

# %%
df = df.drop_duplicates(subset=['id'])
df = df[(~df["annotation"].str.contains("inside scoop")) & (~df["annotation"].str.contains("bio is unreviewed"))].dropna()
df["annotation"] = df["annotation"].apply(clean_description)
df.to_csv("all_songs_no_duplicates.csv")

# %%
cleaned_df.to_csv("cleaned_lyrics_and_descriptions.csv")

# %%
new_df = pd.merge(left=cleaned_df, right=songs_df, left_on="id", right_on="song_id", how="left")
new_df
# Out:
#             id                                             lyrics  \
# 0      4575103  [Chorus: Ed Sheeran]\nOh, I been on for a thou...
# 1      3541694  [Verse 1]\nI will always remember\nThe day you...
# 2      7120781  [Verse 1]\nI had a bad week\nSpent the evening...
# 3      7921365  [Verse 1: Ed Sheeran]\nI had a bad week\nSpent...
# 4       493576  [Verse 1]\nI think I took too much\nI'm addict...
# ...        ...                                                ...
# 13635   193355  [Verse 1]\nBaby, I'm so into you\nYou got that...
# 13636  3199350  [Letra de "Reggaetón Lento (Remix)"]\n[Verse 1...
# 13637   193461  [Verse 1]\nI, I was the game he would play\nHe...
# 13638   218073  [Intro]\nYou wanna?\nYou wanna?\n[Chorus]\nYou...
# 13639   459924  [Intro]\nCrazy\nOh, oh, oh oh\n[Verse 1]\nBaby...
#
#                                               annotation  Unnamed: 0  \
# 0      “1000 Nights” is a collaboration between Ed Sh...           1
# 1      In “2002,” Anne-Marie reminisces about falling...           3
# 2      In an upbeat switch of tone, “2step” is Ed She...           8
# 3      “2step (Remix)” is the fifth single from Ed Sh...          11
# 4      Ed mentions in the Part 2 of his tour diary th...          16
# ...                                                  ...         ...
# 13635  “(You Drive Me) Crazy” is a song recorded by A...         426
# 13636  After the extreme recognition of the song in S...           0
# 13637  \n“You Got It All” is a song recorded by Britn...         428
# 13638  In this hard-hitting club smasher, Britney com...         424
# 13639  “(You Drive Me) Crazy” is a song recorded by A...         427
#
#                artist  artist_id                                    song  \
# 0          Ed Sheeran      12418                             1000 Nights
# 1          Ed Sheeran      12418                                    2002
# 2          Ed Sheeran      12418                                   2step
# 3          Ed Sheeran      12418                           2step (Remix)
# 4          Ed Sheeran      12418                                Addicted
# ...               ...        ...                                     ...
# 13635  Britney Spears       1052                    (You Drive Me) Crazy
# 13636      Little Mix    2774277                 Reggaetón Lento (Remix)
# 13637  Britney Spears       1052                          You Got It All
# 13638  Britney Spears       1052                              Work Bitch
# 13639  Britney Spears       1052  (You Drive Me) Crazy [The Stop Remix!]
#
#        song_id  song_lyrics
# 0      4575103           -1
# 1      3541694           -1
# 2      7120781           -1
# 3      7921365           -1
# 4       493576           -1
# ...        ...          ...
# 13635   193355           -1
# 13636  3199350           -1
# 13637   193461           -1
# 13638   218073           -1
# 13639   459924           -1
#
# [13640 rows x 9 columns]

# %%
new_df = new_df[["id", "lyrics", "annotation", "artist", "artist_id", "song"]]
new_df.to_csv("final_cleaned.csv", index=False)
